# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tv1 = pd.read_csv("./data/torchvision_bs1.csv").reset_index().rename(columns={'index': 'library'})
tv1['library'] = 'TorchVision'

kor1 = pd.read_csv("./data/kornia_bs1.csv").reset_index().rename(columns={'index': 'library'})
kor1['library'] = 'Kornia'

res = pd.concat([tv1, kor1]).set_index(['op_name', 'library'])
res.rename(columns=lambda x: x[-2:], inplace=True)
res.sort_index(inplace=True)
res = res.round(2)

print(res.to_latex())
# Out:
# \begin{tabular}{llrrrrrrrr}
# \toprule
#                    &             &     b0 &     b1 &     b2 &     b3 &     b4 &     b5 &     b6 &     b7 \\
# op\_name & library &        &        &        &        &        &        &        &        \\
# \midrule
# ColorJitter & Kornia &  12.73 &  11.33 &  12.13 &  13.30 &  15.13 &  17.46 &  19.87 &  22.94 \\
#                    & TorchVision &  11.36 &  12.04 &  12.64 &  13.30 &  15.31 &  17.30 &  20.18 &  23.03 \\
# RandomAffine & Kornia &   2.22 &   2.14 &   2.22 &   2.35 &   2.27 &   2.21 &   2.32 &   2.19 \\
#                    & TorchVision &   2.74 &   2.51 &   2.61 &   2.55 &   2.35 &   2.22 &   2.22 &   2.26 \\
# RandomCenterCrop & Kornia &   2.29 &   2.26 &   2.25 &   2.38 &   2.31 &   2.40 &   2.31 &   2.40 \\
#                    & TorchVision &   2.48 &   2.48 &   2.37 &   2.49 &   2.44 &   2.38 &   2.45 &   2.34 \\
# RandomCrop & Kornia &   2.57 &   2.57 &   2.57 &   2.72 &   2.59 &   2.64 &   2.52 &   2.56 \\
#                    & TorchVision &   2.90 &   2.72 &   2.59 &   2.65 &   2.60 &   2.59 &   2.65 &   2.56 \\
# RandomErasing & Kornia &   1.30 &   1.33 &   1.46 &   1.48 &   1.65 &   1.99 &   2.36 &   2.68 \\
#                    & TorchVision &   1.51 &   1.35 &   1.41 &   1.52 &   1.93 &   1.94 &   2.25 &   2.58 \\
# RandomGrayscale & Kornia &   0.62 &   0.56 &   0.60 &   0.56 &   0.59 &   0.57 &   0.74 &   0.57 \\
#                    & TorchVision &   0.68 &   0.59 &   0.61 &   0.59 &   0.59 &   0.59 &   0.72 &   0.60 \\
# RandomHorizontalFlip & Kornia &   0.52 &   0.54 &   0.52 &   0.58 &   0.47 &   0.48 &   0.64 &   0.48 \\
#                    & TorchVision &   0.56 &   0.58 &   0.47 &   0.48 &   0.49 &   0.49 &   0.48 &   0.51 \\
# RandomPerspective & Kornia &   3.84 &   4.02 &   4.02 &   4.27 &   4.34 &   5.05 &   5.55 &   6.25 \\
#                    & TorchVision &   4.70 &   3.88 &   4.08 &   3.99 &   4.44 &   5.14 &   5.44 &   5.73 \\
# RandomResizedCrop & Kornia &   2.99 &   2.92 &   2.98 &   2.88 &   3.05 &   3.02 &   2.89 &   2.88 \\
#                    & TorchVision &   3.27 &   2.97 &   3.15 &   2.96 &   3.04 &   3.04 &   2.96 &   2.97 \\
# RandomRotate & Kornia &   1.95 &   1.84 &   1.87 &   2.01 &   1.95 &   1.90 &   1.94 &   2.02 \\
#                    & TorchVision &   2.08 &   1.93 &   2.08 &   1.92 &   2.01 &   1.94 &   2.07 &   1.93 \\
# RandomVerticalFlip & Kornia &   0.63 &   0.71 &   0.62 &   0.55 &   0.59 &   0.57 &   0.62 &   0.65 \\
#                    & TorchVision &   0.70 &   0.62 &   0.55 &   0.56 &   0.60 &   0.56 &   0.65 &   0.61 \\
# \bottomrule
# \end{tabular}

# %%
res
# Out:
#                                      b0     b1     b2     b3     b4     b5  \
# op_name              library
# ColorJitter          Kornia       12.73  11.33  12.13  13.30  15.13  17.46
#                      TorchVision  11.36  12.04  12.64  13.30  15.31  17.30
# RandomAffine         Kornia        2.22   2.14   2.22   2.35   2.27   2.21
#                      TorchVision   2.74   2.51   2.61   2.55   2.35   2.22
# RandomCenterCrop     Kornia        2.29   2.26   2.25   2.38   2.31   2.40
#                      TorchVision   2.48   2.48   2.37   2.49   2.44   2.38
# RandomCrop           Kornia        2.57   2.57   2.57   2.72   2.59   2.64
#                      TorchVision   2.90   2.72   2.59   2.65   2.60   2.59
# RandomErasing        Kornia        1.30   1.33   1.46   1.48   1.65   1.99
#                      TorchVision   1.51   1.35   1.41   1.52   1.93   1.94
# RandomGrayscale      Kornia        0.62   0.56   0.60   0.56   0.59   0.57
#                      TorchVision   0.68   0.59   0.61   0.59   0.59   0.59
# RandomHorizontalFlip Kornia        0.52   0.54   0.52   0.58   0.47   0.48
#                      TorchVision   0.56   0.58   0.47   0.48   0.49   0.49
# RandomPerspective    Kornia        3.84   4.02   4.02   4.27   4.34   5.05
#                      TorchVision   4.70   3.88   4.08   3.99   4.44   5.14
# RandomResizedCrop    Kornia        2.99   2.92   2.98   2.88   3.05   3.02
#                      TorchVision   3.27   2.97   3.15   2.96   3.04   3.04
# RandomRotate         Kornia        1.95   1.84   1.87   2.01   1.95   1.90
#                      TorchVision   2.08   1.93   2.08   1.92   2.01   1.94
# RandomVerticalFlip   Kornia        0.63   0.71   0.62   0.55   0.59   0.57
#                      TorchVision   0.70   0.62   0.55   0.56   0.60   0.56
#
#                                      b6     b7
# op_name              library
# ColorJitter          Kornia       19.87  22.94
#                      TorchVision  20.18  23.03
# RandomAffine         Kornia        2.32   2.19
#                      TorchVision   2.22   2.26
# RandomCenterCrop     Kornia        2.31   2.40
#                      TorchVision   2.45   2.34
# RandomCrop           Kornia        2.52   2.56
#                      TorchVision   2.65   2.56
# RandomErasing        Kornia        2.36   2.68
#                      TorchVision   2.25   2.58
# RandomGrayscale      Kornia        0.74   0.57
#                      TorchVision   0.72   0.60
# RandomHorizontalFlip Kornia        0.64   0.48
#                      TorchVision   0.48   0.51
# RandomPerspective    Kornia        5.55   6.25
#                      TorchVision   5.44   5.73
# RandomResizedCrop    Kornia        2.89   2.88
#                      TorchVision   2.96   2.97
# RandomRotate         Kornia        1.94   2.02
#                      TorchVision   2.07   1.93
# RandomVerticalFlip   Kornia        0.62   0.65
#                      TorchVision   0.65   0.61

# %%
kor1 = pd.read_csv("./data/kornia_bs1.csv").reset_index().rename(columns={'index': 'batch_size'}).set_index('op_name')
kor1['batch_size'] = 1
kor2 = pd.read_csv("./data/kornia_bs2.csv").reset_index().rename(columns={'index': 'batch_size'}).set_index('op_name') / 2
kor2['batch_size'] = 2
kor4 = pd.read_csv("./data/kornia_bs4.csv").reset_index().rename(columns={'index': 'batch_size'}).set_index('op_name') / 4
kor4['batch_size'] = 4
kor8 = pd.read_csv("./data/kornia_bs8.csv").reset_index().rename(columns={'index': 'batch_size'}).set_index('op_name') / 8
kor8['batch_size'] = 8
kor16 = pd.read_csv("./data/kornia_bs16.csv").reset_index().rename(columns={'index': 'batch_size'}).set_index('op_name') / 16
kor16['batch_size'] = 16
kor32 = pd.read_csv("./data/kornia_bs32.csv").reset_index().rename(columns={'index': 'batch_size'}).set_index('op_name') / 32
kor32['batch_size'] = 32
kor64 = pd.read_csv("./data/kornia_bs64.csv").reset_index().rename(columns={'index': 'batch_size'}).set_index('op_name') / 64
kor64['batch_size'] = 64

merged = pd.concat([kor1, kor2, kor4, kor8, kor16, kor32, kor64]).reset_index().set_index(['op_name', 'batch_size']).sort_index()

# %%
eff_index = 0
plt.figure(figsize=(8, 8))
for op in list(kor1.index):
    selected = merged.iloc[merged.index.get_level_values('op_name') == op].reset_index()[['batch_size', f'efficientnet-b{eff_index}']]
    plt.plot(["1", "2", "4", "8", "16", "32", "64"], selected[f'efficientnet-b{eff_index}'].values, label = op, marker="o")

plt.ylim(ymin=-0.2)
plt.xlim(xmin=-0.2)
plt.legend(bbox_to_anchor=(1.4, 1))
